# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_2024_1 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2024.01.csv', sep=';', decimal=',')
df_2024_2 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2024.02.csv', sep=';', decimal=',')
df_2025_1 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2025.01.csv', sep=';', decimal=',')
df_2025_2 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2025.02.csv', sep=';', decimal=',')
# Out:
# C:\Users\santana.rodrigo\AppData\Local\Temp\ipykernel_17396\3716014408.py:3: DtypeWarning: Columns (0: Regiao - Sigla, 1: Estado - Sigla, 2: Municipio, 3: Revenda, 4: CNPJ da Revenda, 5: Nome da Rua, 6: Numero Rua, 7: Complemento, 8: Bairro, 9: Cep, 10: Produto, 11: Data da Coleta, 12: Unidade de Medida, 13: Bandeira) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2025_1 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2025.01.csv', sep=';', decimal=',')

# %%
# planilhas concatenadas

df = pd.concat([df_2024_1, df_2024_2,
df_2025_1, df_2025_2],
ignore_index=True)
print(df.shape)
display(df.head())
# Out:
# (1712267, 16)
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             AL  ARAPIRACA
# 1             NE             AL  ARAPIRACA
# 2             NE             AL  ARAPIRACA
# 3             NE             AL  ARAPIRACA
# 4             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 1  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 2  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#          Nome da Rua Numero Rua Complemento           Bairro        Cep  \
# 0     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 1     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 2     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 3     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 4  RUA SAO FRANCISCO        274         NaN           CENTRO  57300-080
#
#               Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0            GASOLINA     01/01/2024            5.68              NaN
# 1  GASOLINA ADITIVADA     01/01/2024            5.68              NaN
# 2          DIESEL S10     01/01/2024            5.93              NaN
# 3              ETANOL     01/01/2024            3.99              NaN
# 4            GASOLINA     01/01/2024            5.48              NaN
#
#   Unidade de Medida Bandeira
# 0        R$ / litro    VIBRA
# 1        R$ / litro    VIBRA
# 2        R$ / litro    VIBRA
# 3        R$ / litro    VIBRA
# 4        R$ / litro    VIBRA

# %% [markdown]
# 01
# Construção da base consolidada
# O sistema da ANP exporta os dados por semestre. Antes de qualquer análise, consolide os quatro arquivos de 2024 e 2025
# em um único DataFrame. Confirme que a operação foi realizada corretamente verificando o número de linhas e as
# primeiras entradas do resultado.

# %%
df = pd.concat([df_2024_1, df_2024_2,
df_2025_1, df_2025_2],
ignore_index=True)
print(df.shape)
display(df.head())

#Gráfico
plt.figure(figsize=(10, 8))
plt.barh(df['Estado - Sigla'],df[ 'Valor de Venda'], color='steelblue')
plt.title('Preço Médio da Gasolina C por Estado — ANP 2024–2025')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# (1712267, 16)
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             AL  ARAPIRACA
# 1             NE             AL  ARAPIRACA
# 2             NE             AL  ARAPIRACA
# 3             NE             AL  ARAPIRACA
# 4             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 1  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 2  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#          Nome da Rua Numero Rua Complemento           Bairro        Cep  \
# 0     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 1     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 2     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 3     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 4  RUA SAO FRANCISCO        274         NaN           CENTRO  57300-080
#
#               Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0            GASOLINA     01/01/2024            5.68              NaN
# 1  GASOLINA ADITIVADA     01/01/2024            5.68              NaN
# 2          DIESEL S10     01/01/2024            5.93              NaN
# 3              ETANOL     01/01/2024            3.99              NaN
# 4            GASOLINA     01/01/2024            5.48              NaN
#
#   Unidade de Medida Bandeira
# 0        R$ / litro    VIBRA
# 1        R$ / litro    VIBRA
# 2        R$ / litro    VIBRA
# 3        R$ / litro    VIBRA
# 4        R$ / litro    VIBRA
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 9
#       5 display(df.head())
#       6
#       7 #Gráfico
#       8 plt.figure(figsize=(10, 8))
# ----> 9 plt.barh(df['Estado - Sigla'],df[ 'Valor de Venda'], color='steelblue')
#      10 plt.title('Preço Médio da Gasolina C por Estado — ANP 2024–2025')
#      11 plt.xticks(rotation=45)
#      12 plt.tight_layout()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:3018, in barh(y, width, height, left, align, data, **kwargs)
#    3007 @_copy_docstring_and_deprecators(Axes.barh)
#    3008 def barh(
#    3009     y: float | ArrayLike,
#    (...)   3016     **kwargs,
#    3017 ) -> BarContainer:
# -> 3018     return gca().barh(
#    3019         y,
#    3020         width,
#    3021         height=height,
#    3022         left=left,
#    3023         align=align,
#    3024         **({"data": data} if data is not None else {}),
#    3025         **kwargs,
#    3026     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_axes.py:2834, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2704 r"""
#    2705 Make a horizontal bar plot.
#    2706
#    (...)   2831 :doc:`/gallery/lines_bars_and_markers/horizontal_barchart_distribution`.
#    2832 """
#    2833 kwargs.setdefault('orientation', 'horizontal')
# -> 2834 patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2835                    align=align, data=data, **kwargs)
#    2836 return patches
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_axes.py:2563, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2558         self.set_yscale('log', nonpositive='clip')
#    2559 else:  # horizontal
#    2560     # It is possible for x (left) to contain unit information.
#    2561     # However, it is also possible for x=0 for the default and width
#    2562     # to contain unit information.  This will prioritize the units of x.
# -> 2563     self._process_unit_info(
#    2564         [("x", x), ("x", width), ("y", y)], kwargs, convert=False)
#    2565     if log:
#    2566         self.set_xscale('log', nonpositive='clip')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_base.py:2663, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2661     # Update from data if axis is already set but no unit is set yet.
#    2662     if axis is not None and data is not None and not axis.have_units():
# -> 2663         axis.update_units(data)
#    2664 for axis_name, axis in axis_map.items():
#    2665     # Return if no axis is set.
#    2666     if axis is None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\_api\__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %% [markdown]
# 02
# Gasolina C no Rio de Janeiro
# O diretor quer entender como se comportaram os preços médios da Gasolina C no estado do Rio de Janeiro entre 2024 e
# 2025. Calcule a média do Valor de Venda por município e apresente os resultados do maior para o menor. Quais municípios
# praticaram os maiores preços médios no período?

# %%
import matplotlib.pyplot as plt

# %%
# Preco medio praticado no periodo
media_geral = df['Valor de Venda'].mean()
print(media_geral)
# Gráfico
plt.figure(figsize=(10, 8))
plt.barh(fat_estado['Estado - Sigla'], fat_estado['Valor de Venda'], color='steelblue')
plt.title('Preço Médio da Gasolina C por Estado — ANP 2024–2025')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# 5.692053591192336
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 6
#       2 media_geral = df['Valor de Venda'].mean()
#       3 print(media_geral)
#       4 # Gráfico
#       5 plt.figure(figsize=(10, 8))
# ----> 6 plt.barh(fat_estado['Estado - Sigla'], fat_estado['Valor de Venda'], color='steelblue')
#       7 plt.title('Preço Médio da Gasolina C por Estado — ANP 2024–2025')
#       8 plt.xticks(rotation=0)
#       9 plt.tight_layout()
#
# NameError: name 'fat_estado' is not defined

# %%
# Preço médio por estado
estado_media = (
    df.groupby('Estado - Sigla')['Valor de Venda']
      .mean()
      .reset_index()
)

# Gráfico
plt.figure(figsize=(10, 8))
plt.barh(
    estado_media['Estado - Sigla'],
    estado_media['Valor de Venda'],
    color='steelblue'
)
plt.title('Preço Médio da Gasolina C por Estado — ANP 2024–2025')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# 03
# Outliers de preço: Gasolina C no RJ
#
# Ainda com foco na Gasolina C no Rio de Janeiro, identifique os postos com preços estatisticamente atípicos. Calcule o IQR e
# os limites para o Valor de Venda. Existem postos praticando preços fora do padrão? Apresente os grupos de outliers
# superiores e inferiores ordenados de forma adequada. Se o limite inferior for negativo, o que isso indica?

# %%
array_valor_outlier = np.array(df['Valor de Venda'])
q1 = np.percentile(array_valor_outlier, 25)
q3 = np.percentile(array_valor_outlier, 75)
iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 - (1.5 * iqr)
#print(q1)
#print(q3)
print(f'Limite Superior: {limite_superior}')
print(f'Limite Inderiir: {limite_inferior}')
# Out:
# Limite Superior: nan
# Limite Inderiir: nan

# %% [markdown]
# 04
# Comparando estados: Etanol Hidratado
# O diretor quer comparar o preço médio do Etanol Hidratado entre RJ e SP em 2024 e 2025. Filtre os dados para os dois
# estados e calcule a média do Valor de Venda para cada um. Em seguida, aplique o critério de outliers em cada estado
# separadamente. Os limites e os casos atípicos são semelhantes ou diferentes entre os dois estados?

# %%
df_rj_sp_etanol = df.loc[(df['Estado - Sigla'].isin(['RJ','SP'])) & (df['Produto'] =='ETANOL')]

df_media_eta_rjsp = df_media_eta_rjsp.groupby('Estado - Sigla')['Valor de Venda'].mean().reset_index()

df_media_eta_rjsp.sort_values(by='Valor de Venda', ascending=False,inplace=True)

df_media_eta_rjsp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 df_rj_sp_etanol = df.loc[(df['Estado - Sigla'].isin(['RJ','SP'])) & (df['Produto'] =='ETANOL')]
#       2
# ----> 3 df_media_eta_rjsp = df_media_eta_rjsp.groupby('Estado - Sigla')['Valor de Venda'].mean().reset_index()
#       4
#       5 df_media_eta_rjsp.sort_values(by='Valor de Venda', ascending=False,inplace=True)
#       6
#
# NameError: name 'df_media_eta_rjsp' is not defined

# %% [markdown]
# 05
# Bairros da capital: preços dentro ou fora do padrão?
# A diretoria quer entender como os preços da Gasolina C se distribuem entre os diferentes bairros da cidade do Rio de
# Janeiro. Existem bairros com dados atípicos?
# A partir desse recorte:
# 1
# Calcule a média do Valor de Venda por bairro (coluna Bairro) e ordene do maior para o menor.
# 2 Aplique o IQR para identificar bairros com preços médios estatisticamente atípicos — tanto os superiores quanto os
# inferiores.
# 3 Os bairros outliers superiores são regiões nobres da cidade? Os inferiores são periferias ou regiões com alta
# concorrência? Apresente sua conclusão.

# %%
# Preco medio da Gasolina C por semana — ANP 2024-2025
preco_tempo = df_gas.groupby('Data da Coleta')['Valor de Venda'].mean()
plt.figure(figsize=(14, 4)) 
plt.plot(preco_tempo.index, preco_tempo.values, color='steelblue')
plt.title('Evolução do Preço Médio da Gasolina C — Brasil 2024–2025') 
plt.xticks(rotation=45) 
plt.tight_layout() plt.show()
# Out:
#   Cell In[41], line 7
#     plt.tight_layout() plt.show()
#                        ^
# SyntaxError: invalid syntax
